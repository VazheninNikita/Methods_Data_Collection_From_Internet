# %% [markdown]
# ### Задание 1

# %% [markdown]
# 1) Сгенерировал токен

# %%
# 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

# %% [markdown]
# 2) Подключаю библиотеки

# %%
import requests
import json

# %% [markdown]
# 3) Создаю переменные с именем пользователя, чьи репозитории хочу посмотреть, и со сгенерированным токеном для использования в методе GET

# %%
username = 'VazheninNikita'
token = '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'

# %% [markdown]
# 4) Выполняю запрос с аутентификацией

# %%
r = requests.get('https://api.github.com/user', auth=(username, token))

# %%
r.text
# Out:
# '{"login":"VazheninNikita","id":78304369,"node_id":"MDQ6VXNlcjc4MzA0MzY5","avatar_url":"https://avatars.githubusercontent.com/u/78304369?v=4","gravatar_id":"","url":"https://api.github.com/users/VazheninNikita","html_url":"https://github.com/VazheninNikita","followers_url":"https://api.github.com/users/VazheninNikita/followers","following_url":"https://api.github.com/users/VazheninNikita/following{/other_user}","gists_url":"https://api.github.com/users/VazheninNikita/gists{/gist_id}","starred_url":"https://api.github.com/users/VazheninNikita/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/VazheninNikita/subscriptions","organizations_url":"https://api.github.com/users/VazheninNikita/orgs","repos_url":"https://api.github.com/users/VazheninNikita/repos","events_url":"https://api.github.com/users/VazheninNikita/events{/privacy}","received_events_url":"https://api.github.com/users/VazheninNikita/received_events","type":"User","site_admin":false,"name":null,"compa
# ...

# %% [markdown]
# 5) Преобразую полученный результат json в объекты python

# %%
r.json()
# Out:
# {'login': 'VazheninNikita',
#  'id': 78304369,
#  'node_id': 'MDQ6VXNlcjc4MzA0MzY5',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/78304369?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/VazheninNikita',
#  'html_url': 'https://github.com/VazheninNikita',
#  'followers_url': 'https://api.github.com/users/VazheninNikita/followers',
#  'following_url': 'https://api.github.com/users/VazheninNikita/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/VazheninNikita/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/VazheninNikita/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/VazheninNikita/subscriptions',
#  'organizations_url': 'https://api.github.com/users/VazheninNikita/orgs',
#  'repos_url': 'https://api.github.com/users/VazheninNikita/repos',
#  'events_url': 'https://api.github.com/users/VazheninNikita/events{/privacy}',
# ...

# %% [markdown]
# 6) Получаю информацию о всех репозиториях пользователя

# %%
repos = requests.get('https://api.github.com/user/repos', auth=(username, token))

# %% [markdown]
# 7) Вывожу информацию по одному из репозиториев для примера

# %%
repos.json()[1]
# Out:
# {'id': 334652088,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMzQ2NTIwODg=',
#  'name': 'Python',
#  'full_name': 'VazheninNikita/Python',
#  'private': False,
#  'owner': {'login': 'VazheninNikita',
#   'id': 78304369,
#   'node_id': 'MDQ6VXNlcjc4MzA0MzY5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/78304369?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/VazheninNikita',
#   'html_url': 'https://github.com/VazheninNikita',
#   'followers_url': 'https://api.github.com/users/VazheninNikita/followers',
#   'following_url': 'https://api.github.com/users/VazheninNikita/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/VazheninNikita/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/VazheninNikita/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/VazheninNikita/subscriptions',
#   'organizations_url': 'https://api.github.com/users/VazheninNikita/orgs',
# ...

# %% [markdown]
# 8) Вывожу ссылки на все репозитории пользователя

# %%
for repo in repos.json():
    print(repo['html_url'])
# Out:
# https://github.com/VazheninNikita/MySQL
# https://github.com/VazheninNikita/Python
# https://github.com/VazheninNikita/Python_libs

# %% [markdown]
# 9) Вывожу наименования всех репозиториев пользователя

# %%
print(f"У пользователя {username} имеются следующие репозитории:")
for repo in repos.json():
    print(repo['name'])
# Out:
# У пользователя VazheninNikita имеются следующие репозитории:
# MySQL
# Python
# Python_libs

# %% [markdown]
# 10) Преобразую объект python в сериализованную строку json

# %%
json_data = json.dumps(repos.json(), indent=4)
print(json_data)
# Out:
# [
#     {
#         "id": 372539611,
#         "node_id": "MDEwOlJlcG9zaXRvcnkzNzI1Mzk2MTE=",
#         "name": "MySQL",
#         "full_name": "VazheninNikita/MySQL",
#         "private": false,
#         "owner": {
#             "login": "VazheninNikita",
#             "id": 78304369,
#             "node_id": "MDQ6VXNlcjc4MzA0MzY5",
#             "avatar_url": "https://avatars.githubusercontent.com/u/78304369?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/VazheninNikita",
#             "html_url": "https://github.com/VazheninNikita",
#             "followers_url": "https://api.github.com/users/VazheninNikita/followers",
#             "following_url": "https://api.github.com/users/VazheninNikita/following{/other_user}",
#             "gists_url": "https://api.github.com/users/VazheninNikita/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/VazheninNikita/starred{/owner}{/repo}",
# ...

# %% [markdown]
# 11) Сохраняю в файл .json

# %%
with open('json_data.json', 'w') as outfile:
    json.dump(json_data, outfile)

# %% [markdown]
# 12) Проверка файла .json

# %%
with open('json_data.json') as json_file:
    data = json.load(json_file)

    print(json_data)
# Out:
# [
#     {
#         "id": 372539611,
#         "node_id": "MDEwOlJlcG9zaXRvcnkzNzI1Mzk2MTE=",
#         "name": "MySQL",
#         "full_name": "VazheninNikita/MySQL",
#         "private": false,
#         "owner": {
#             "login": "VazheninNikita",
#             "id": 78304369,
#             "node_id": "MDQ6VXNlcjc4MzA0MzY5",
#             "avatar_url": "https://avatars.githubusercontent.com/u/78304369?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/VazheninNikita",
#             "html_url": "https://github.com/VazheninNikita",
#             "followers_url": "https://api.github.com/users/VazheninNikita/followers",
#             "following_url": "https://api.github.com/users/VazheninNikita/following{/other_user}",
#             "gists_url": "https://api.github.com/users/VazheninNikita/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/VazheninNikita/starred{/owner}{/repo}",
# ...
